# %%
Record = {101:{"ProductName":"Glue","ManufacturingDate":"14-July-2021","Quantity":40,"Price":20,"Status":"Available"},
          102:{"ProductName":"A4 Paper","ManufacturingDate":"24-August-2021","Quantity":500,"Price":5,"Status":"Available"},
          103:{"ProductName":"Pencil","ManufacturingDate":"06-July-2021","Quantity":60,"Price":5,"Status":"Available"},
          104:{"ProductName":"Eraser","ManufacturingDate":"04-April-2021","Quantity":45,"Price":10,"Status":"Available"},
          105:{"ProductName":"Stapler","ManufacturingDate":"19-August-2021","Quantity":40,"Price":40,"Status":"Available"},
          106:{"ProductName":"Paper Clip","ManufacturingDate":"12-August-2021","Quantity":70,"Price":10,"Status":"Available"},
          107:{"ProductName":"Highlighter","ManufacturingDate":"03-August-2021","Quantity":55,"Price":50,"Status":"Available"},
          108:{"ProductName":"Black Pen","ManufacturingDate":"06-June-2021","Quantity":70,"Price":10,"Status":"Available"},
          109:{"ProductName":"Blue Pen","ManufacturingDate":"08-June-2021","Quantity":100,"Price":10,"Status":"Available"},
          110:{"ProductName":"Red Pen","ManufacturingDate":"31-August-2021","Quantity":60,"Price":10,"Status":"Available"},
          111:{"ProductName":"Green Pen","ManufacturingDate":"09-May-2021","Quantity":50,"Price":10,"Status":"Available"},
          112:{"ProductName":"Scissor","ManufacturingDate":"02-August-2021","Quantity":40,"Price":30,"Status":"Available"},
          113:{"ProductName":"Small Notebook","ManufacturingDate":"02-August-2021","Quantity":80,"Price":35,"Status":"Available"},
          114:{"ProductName":"Calculator","ManufacturingDate":"01-September-2021","Quantity":30,"Price":100,"Status":"Available"},
          115:{"ProductName":"Tape","ManufacturingDate":"14-March-2021","Quantity":65,"Price":10,"Status":"Available"},
          116:{"ProductName":"Label","ManufacturingDate":"16-August-2021","Quantity":30,"Price":5,"Status":"Available"},
          117:{"ProductName":"Pencil Sharpener","ManufacturingDate":"21-May-2021","Quantity":65,"Price":5,"Status":"Available"},
          118:{"ProductName":"Envelope","ManufacturingDate":"09-June-2021","Quantity":40,"Price":2,"Status":"Available"},
          119:{"ProductName":"Blue Ink","ManufacturingDate":"18-August-2021","Quantity":50,"Price":30,"Status":"Available"},
          120:{"ProductName":"Black Ink","ManufacturingDate":"25-July-2021","Quantity":50,"Price":35,"Status":"Available"},
          121:{"ProductName":"Crayons","ManufacturingDate":"13-June-2021","Quantity":55,"Price":20,"Status":"Available"},
          122:{"ProductName":"Whitener Pen","ManufacturingDate":"14-May-2021","Quantity":50,"Price":30,"Status":"Available"},
          123:{"ProductName":"Marker","ManufacturingDate":"01-March-2021","Quantity":40,"Price":45,"Status":"Available"},
          124:{"ProductName":"File","ManufacturingDate":"07-March-2021","Quantity":55,"Price":40,"Status":"Available"},
          125:{"ProductName":"Scale Long","ManufacturingDate":"19-June-2021","Quantity":60,"Price":20,"Status":"Available"},
          126:{"ProductName":"Scale Small","ManufacturingDate":"24-July-2021","Quantity":85,"Price":15,"Status":"Available"},
          127:{"ProductName":"Long Notebook","ManufacturingDate":"28-May-2021","Quantity":50,"Price":60,"Status":"Available"},
          128:{"ProductName":"A4 Notebook","ManufacturingDate":"12-June-2021","Quantity":100,"Price":45,"Status":"Available"},
          129:{"ProductName":"White Chart","ManufacturingDate":"23-June-2021","Quantity":110,"Price":10,"Status":"Available"},
          130:{"ProductName":"Black Chart","ManufacturingDate":"04-July-2021","Quantity":75,"Price":10,"Status":"Available"}}

# %%
import json
import time

# %%
R= json.dumps(Record)

# %%
fd = open("Record.json",'w')
Records=fd.write(R)
fd.close()

fd = open("Record.json",'r')
fd.read()
fd.close()

Record = json.loads(R)

# %%
print("HELLO!!!! WELCOME TO OUR SHOP")
print("                                            ")
tell=input("Want to Sell (Yes or No)? ")
if (tell=='Yes' or tell=='yes'):
    ProductId = int(input("Enter Product Id: "))
    if ProductId in Record.keys():
        ManufacturingDate=Record[ProductId]['ManufacturingDate']
        ProductName = Record[ProductId]['ProductName']
        Quantity1 = int(input("Enter Quantity: "))
        Price=int(input("Enter Price: "))
        Status=str(input("Enter Status Available or Not Available: "))
        q=int(Record[ProductId]['Quantity']) + Quantity1
        d= {ProductId :{'ProductName': ProductName, 'ManufacturingDate': ManufacturingDate, 'Quantity': q,'Price': Price, 'Status': Status}}
        Record.update(d)
    else:
        ManufacturingDate=str(input("Enter Manufacturing Date dd-mm-yy format: "))
        ProductName = str(input("Enter Product Name: "))
        Quantity1 = int(input("Enter Quantity: "))
        Price=int(input("Enter Price: "))
        Status=str(input("Enter Status Available or Not Available: "))
        Record[ProductId] = {'ProductName': ProductName, 'ManufacturingDate': ManufacturingDate, 'Quantity': Quantity1,'Price': Price, 'Status':Status}
    print("                                  ")
    print("THANK YOU FOR SELLING YOUR PRODUCT")
    
    js = json.dumps(Record)

    fd = open("Record.json",'w')
    fd.write(js)
    fd.close()
    
elif (tell=='No' or tell=='no'):
    print("                                   ")
    tell2=input("Want to Purchase (Yes or No)?")
    if (tell2=='Yes' or tell2=='yes'):
        Name=input("Enter Your Name : ")
        Phone_Number=int(input("Enter Your 10 Digit Phone Number : "))
        print("1.Glue(ProductID=101)\n2.A4 Paper(ProductID=102)\n3.PencilEraser(ProductID=103)\n4.Eraser(ProductID=104)\n5.Stapler(ProductID=105)\n6.Paper Clip(ProductID=106)\n7.Highlighter(ProductID=107)\n8.Black Pen(ProductID=108)\n9.Blue Pen(ProductID=109)\n10.Red Pen(ProductID=110)\n11.Green Pen(ProductID=111)\n12.Scissor(ProductID=112)\n13.Small Notebook(ProductID=113)\n14.Calculator(ProductID=114)\n15.Tape(ProductID=115)\n16.Label(ProductID=116)\n17.Pencil Sharpener(ProductID=117)\n18.Envelope(ProductID=118)\n19.Blue Ink(ProductID=119)\n20.Black Ink(ProductID=120)\n21.Crayons(ProductID=121)\n22.Whitener Pen(ProductID=122)\n23.Marker(ProductID=123)\n24.File(ProductID=124)\n25.Scale Long(ProductID=125)\n26.Scale Small(ProductID=126)\n27.Long Notebook(ProductID=127)\n28.A4 Notebook(ProductID=128)\n29.White Chart(ProductID=129)\n30.Black Chart(ProductID=130)")
        Item_ID=str(input("Enter the Item ID You Want to Purchase : "))
        Quantity=int(input("How Many? "))
        print("*********************************************")
        print("/////////////////YOUR  BILL//////////////////")
        print("                                             ")        
        t=time.ctime()
        print("Date & Time :",t)
        print("Customer Name : ",Name)
        print("Customer Phone Number : ",Phone_Number)
        print("Items ID: ", Item_ID)
        print("Product Name: ", Record[Item_ID]["ProductName"])
        print("Manufacturing Date: ", Record[Item_ID]["ManufacturingDate"])
        print("Price: ",Record[Item_ID]["Price"],"rs/-")
        print("Quantity: ",Quantity)
        print("---------------------------------------------")
        print("Billing Amout : ", Quantity * int(Record[Item_ID]["Price"]),"rs/-")
        print("---------------------------------------------")
        print("                                             ")
        print("///////////THANK YOU FOR SHOPPING////////////")
        print("*********************************************")

        Record[Item_ID]['Quantity'] = Record[Item_ID]['Quantity'] - Quantity
        if(Record[Item_ID]['Quantity']<=0):
            Record[Item_ID]['Status']='Not Available'        
        js = json.dumps(Record)

        fd = open("Record.json",'w')
        fd.write(js)
        fd.close()

        Sales={'ProductId' : Item_ID, 'ProductName' : Record[Item_ID]['ProductName'],'ManufacturingDate' : Record[Item_ID]['ManufacturingDate'],'Quantity' : Quantity, 'Amount': Record[Item_ID]['Price'] * Quantity, 'Time': t}
        R= json.dumps(Sales)
        fd = open("Sales.json",'w')
        fd.write(R)
        fd.close()
    else:
        print("         ")
        print("Thank You😊")
else:
    print("                    ")
    print("Something Went Wrong🙁")
# Out:
# HELLO!!!! WELCOME TO OUR SHOP
#
# Want to Sell (Yes or No)? no
#
# Want to Purchase (Yes or No)?yes
# Enter Your Name : bh
# Enter Your 10 Digit Phone Number : 2929929292
# 1.Glue(ProductID=101)
# 2.A4 Paper(ProductID=102)
# 3.PencilEraser(ProductID=103)
# 4.Eraser(ProductID=104)
# 5.Stapler(ProductID=105)
# 6.Paper Clip(ProductID=106)
# 7.Highlighter(ProductID=107)
# 8.Black Pen(ProductID=108)
# 9.Blue Pen(ProductID=109)
# 10.Red Pen(ProductID=110)
# 11.Green Pen(ProductID=111)
# 12.Scissor(ProductID=112)
# 13.Small Notebook(ProductID=113)
# 14.Calculator(ProductID=114)
# 15.Tape(ProductID=115)
# 16.Label(ProductID=116)
# 17.Pencil Sharpener(ProductID=117)
# 18.Envelope(ProductID=118)
# 19.Blue Ink(ProductID=119)
# 20.Black Ink(ProductID=120)
# 21.Crayons(ProductID=121)
# 22.Whitener Pen(ProductID=122)
# 23.Marker(ProductID=123)
# 24.File(ProductID=124)
# 25.Scale Long(ProductID=125)
# 26.Scale Small(ProductID=126)
# 27.Long Notebook(ProductID=127)
# 28.A4 Notebook(ProductID=128)
# ...
